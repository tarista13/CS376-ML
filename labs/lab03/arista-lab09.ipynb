# %% [markdown]
# # Logits in Causal Language Models
#
# Task: Ask a language model for how likely each token is to be the next one.

# %% [markdown]
# ## Setup

# %% [markdown]
# We start in the same way as the tokenization notebook:

# %%
# If the import fails, uncomment the following line:
# !pip install transformers
import torch
from torch import tensor
from transformers import AutoTokenizer, AutoModelForCausalLM
import pandas as pd
# Avoid a warning message
import os; os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# One step in this notebook will ask you to write a function. The most common error when function-ifying notebook code is accidentally using a global variable instead of a value computed in the function. This is a quick and dirty little utility to check for that mistake. (For a more polished version, check out [`localscope`](https://localscope.readthedocs.io/en/latest/README.html).)

# %%
def check_global_vars(func, allowed_globals):
    import inspect
    used_globals = set(inspect.getclosurevars(func).globals.keys())
    disallowed_globals = used_globals - set(allowed_globals)
    if len(disallowed_globals) > 0:
        raise AssertionError(f"The function {func.__name__} used unexpected global variables: {list(disallowed_globals)}")

# %% [markdown]
# Download and load the model.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, set_seed
model_name = "openai-community/gpt2"
# Here's a few larger models you could try:
# model_name = "EleutherAI/pythia-1.4b-deduped"
# model_name = "google/gemma-2b"
# model_name = "google/gemma-2b-it"
# Note: you'll need to accept the license agreement on https://huggingface.co/google/gemma-7b to use Gemma models
tokenizer = AutoTokenizer.from_pretrained(model_name, add_prefix_space=True)

# add the EOS token as PAD token to avoid warnings
model = AutoModelForCausalLM.from_pretrained(model_name)
if model.generation_config.pad_token_id is None:
    model.generation_config.pad_token_id = model.generation_config.eos_token_id
# Silence a warning.
tokenizer.decode([tokenizer.eos_token_id]);

# %%
print(f"The tokenizer has {len(tokenizer.get_vocab())} strings in its vocabulary.")
print(f"The model has {model.num_parameters():,d} parameters.")
# Out:
# The tokenizer has 50257 strings in its vocabulary.
# The model has 124,439,808 parameters.

# %% [markdown]
# ## Task
#
# In the tokenization notebook, we simply used the `generate` method to have the model generate some text. Now we'll do it ourselves.
#
# Consider the following phrase:

# %%
phrase = "This weekend I plan to"
# Another one to try later. This was a famous early example of the GPT-2 model:
# phrase = "In a shocking finding, scientists discovered a herd of unicorns living in"

# %% [markdown]
# 1: Call the `tokenizer` on the phrase to get a `batch`. After having a look at what goes in the `batch`, extract the `input_ids`.

# %%
batch = tokenizer(phrase, return_tensors='pt')
input_ids = batch['input_ids']

# %% [markdown]
# 2: Call the `model` on the `input_ids`. Examine the shape of the logits; what does each number mean?
#
# Note: The `model` returns an object that has multiple values. The `logits` are in `model_output.logits`.

# %%
with torch.no_grad(): # This tells PyTorch we don't need it to compute gradients for us.
    model_output = model(input_ids)
print(f"logits shape: {list(model_output.logits.shape)}")
# Out:
# logits shape: [1, 5, 50257]

# %% [markdown]
# [batch size, # of tokens, ]

# %% [markdown]
# 3: Pull out the logits corresponding to the *last* token in the input phrase. Hint: Think about what each number in the shape means.

# %%
last_token_logits = model_output.logits[0, -1, :]
assert last_token_logits.shape == (len(tokenizer.get_vocab()),)

# %% [markdown]
# 4: Identify the token id and corresponding string of the most likely next token.
#
# To find the most likely token, we need to find the *index* of the *largest value* in the `last_token_logits`. The method that does this is called `argmax`. (It's a common enough operation that it's built into PyTorch.)
#
# Note: The `tokenizer` has a `decode` method that takes a token id, or a list of token ids, and returns the corresponding string.

# %%
# compute the probability distribution over the next token
last_token_probabilities = last_token_logits.softmax(dim=-1)
# dim=-1 means to compute the softmax over the last dimension

# %%
most_likely_token_id = last_token_probabilities.argmax()
decoded_token = tokenizer.decode(most_likely_token_id)
probability_of_most_likely_token = last_token_probabilities[most_likely_token_id].item()

print("For the phrase:", phrase)
print(f"Most likely next token: {most_likely_token_id}, which corresponds to {repr(decoded_token)}, with probability {probability_of_most_likely_token:.2%}")
# Out:
# For the phrase: This weekend I plan to
# Most likely next token: 467, which corresponds to ' go', with probability 5.79%

# %% [markdown]
# 5: Use the `topk` method to find the top-10 most likely choices for the next token.
#
# See the documentation for [`torch.topk`](https://pytorch.org/docs/stable/generated/torch.topk.html). Calling `topk` on a tensor returns a named tuple with two tensors: `values` and `indices`. The `values` are the top-k values, and the `indices` are the indices of those values in the original tensor. (In this case, the indices are the token ids.)
#
# *Note*: This uses Pandas to make a nicely displayed table, and a *list comprehension* to decode the tokens. You don't *need* to understand how this all works, but I highly encourage thinking about what's going on.

# %%
most_likely_tokens = last_token_logits.topk(10)
print(f"most likely token index from topk is {most_likely_tokens.indices[0]}") # this should be the same as argmax
decoded_tokens = [tokenizer.decode(token_id) for token_id in most_likely_tokens.indices]
probabilities_of_most_likely_tokens = last_token_probabilities[most_likely_tokens.indices]

# Make a nice table to show the results
most_likely_tokens_df = pd.DataFrame({
    'tokens': decoded_tokens,
    'probabilities': probabilities_of_most_likely_tokens,
})
# Show the table, in a nice formatted way (see https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#Builtin-Styles)
# Caution: this "gradient" has *nothing* to do with gradient descent! (It's a color gradient.)
most_likely_tokens_df.style.hide(axis='index').background_gradient()
# Out:
# most likely token index from topk is 467
# <style type="text/css">
# #T_25c69_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_25c69_row1_col1 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_25c69_row2_col1 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_25c69_row3_col1 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_25c69_row4_col1 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_25c69_row5_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_25c69_row6_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_25c69_row7_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_25c69_row8_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_25c69_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_25c69">
#   <thead>
#     <tr>
#       <th id="T_25c69_level0_col0" class="col_heading level0 col0" >tokens</th>
#       <th id="T_25c69_level0_col1" class="col_heading level0 col1" >probabilities</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_25c69_row0_col0" class="data row0 col0" > go</td>
#       <td id="T_25c69_row0_col1" class="data row0 col1" >0.057940</td>
#     </tr>
#     <tr>
#       <td id="T_25c69_row1_col0" class="data row1 col0" > take</td>
#       <td id="T_25c69_row1_col1" class="data row1 col1" >0.053054</td>
#     </tr>
#     <tr>
#       <td id="T_25c69_row2_col0" class="data row2 col0" > attend</td>
#       <td id="T_25c69_row2_col1" class="data row2 col1" >0.038624</td>
#     </tr>
#     <tr>
#       <td id="T_25c69_row3_col0" class="data row3 col0" > visit</td>
#       <td id="T_25c69_row3_col1" class="data row3 col1" >0.036411</td>
#     </tr>
#     <tr>
#       <td id="T_25c69_row4_col0" class="data row4 col0" > be</td>
#       <td id="T_25c69_row4_col1" class="data row4 col1" >0.027353</td>
#     </tr>
#     <tr>
#       <td id="T_25c69_row5_col0" class="data row5 col0" > do</td>
#       <td id="T_25c69_row5_col1" class="data row5 col1" >0.024955</td>
#     </tr>
#     <tr>
#       <td id="T_25c69_row6_col0" class="data row6 col0" > make</td>
#       <td id="T_25c69_row6_col1" class="data row6 col1" >0.023817</td>
#     </tr>
#     <tr>
#       <td id="T_25c69_row7_col0" class="data row7 col0" > spend</td>
#       <td id="T_25c69_row7_col1" class="data row7 col1" >0.021306</td>
#     </tr>
#     <tr>
#       <td id="T_25c69_row8_col0" class="data row8 col0" > play</td>
#       <td id="T_25c69_row8_col1" class="data row8 col1" >0.019173</td>
#     </tr>
#     <tr>
#       <td id="T_25c69_row9_col0" class="data row9 col0" > travel</td>
#       <td id="T_25c69_row9_col1" class="data row9 col1" >0.017759</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 6. Write a function that is given a phrase and a *k* and returns the `most_likely_tokens_df` DataFrame with the top *k* most likely next tokens. (Don't include the `style` line.)
#
# Build this function using only code that you've already filled in above. Clean up the code so that it doesn't do or display anything extraneous. Add comments about what each step does.

# %%
def predict_next_tokens(phrase, k):
    # Call the tokenizer on the phrase to get a batch
    batch = tokenizer(phrase, return_tensors='pt')
    input_ids = batch['input_ids']
    
    # Call the model on the input_ids
    with torch.no_grad():
        model_output = model(input_ids)
    
    # Pull out the logits corresponding to the last token in the input phrase
    last_token_logits = model_output.logits[0, -3, :]
    assert last_token_logits.shape == (len(tokenizer.get_vocab()),)
    
    # Compute the probability distribution over the next token
    last_token_probabilities = last_token_logits.softmax(dim=-1)
    
    # Use the topk method to find the top-k most likely choices for the next token
    most_likely_tokens = last_token_logits.topk(k)
    
    decoded_tokens = [tokenizer.decode(token_id) for token_id in most_likely_tokens.indices]
    probabilities_of_most_likely_tokens = last_token_probabilities[most_likely_tokens.indices]
    
    # Make a DataFrame to show the results
    most_likely_tokens_df = pd.DataFrame({
        'tokens': decoded_tokens,
        'probabilities': probabilities_of_most_likely_tokens,
    })
    
    return most_likely_tokens_df

def show_tokens_df(tokens_df):
    return tokens_df.style.hide(axis='index').background_gradient()

check_global_vars(predict_next_tokens, allowed_globals=["torch", "tokenizer", "pd", "model"])

# %%
show_tokens_df(predict_next_tokens("This weekend I plan to", 5))
# Out:
# <style type="text/css">
# #T_cf673_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_cf673_row1_col1 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_cf673_row2_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_cf673_row3_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_cf673_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_cf673">
#   <thead>
#     <tr>
#       <th id="T_cf673_level0_col0" class="col_heading level0 col0" >tokens</th>
#       <th id="T_cf673_level0_col1" class="col_heading level0 col1" >probabilities</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cf673_row0_col0" class="data row0 col0" > was</td>
#       <td id="T_cf673_row0_col1" class="data row0 col1" >0.107942</td>
#     </tr>
#     <tr>
#       <td id="T_cf673_row1_col0" class="data row1 col0" > will</td>
#       <td id="T_cf673_row1_col1" class="data row1 col1" >0.064832</td>
#     </tr>
#     <tr>
#       <td id="T_cf673_row2_col0" class="data row2 col0" >'ll</td>
#       <td id="T_cf673_row2_col1" class="data row2 col1" >0.052473</td>
#     </tr>
#     <tr>
#       <td id="T_cf673_row3_col0" class="data row3 col0" > had</td>
#       <td id="T_cf673_row3_col1" class="data row3 col1" >0.045029</td>
#     </tr>
#     <tr>
#       <td id="T_cf673_row4_col0" class="data row4 col0" > went</td>
#       <td id="T_cf673_row4_col1" class="data row4 col1" >0.042392</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_tokens_df(predict_next_tokens("To be or not to", 5))
# Out:
# <style type="text/css">
# #T_2c1f8_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2c1f8_row1_col1 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_2c1f8_row2_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_2c1f8_row3_col1, #T_2c1f8_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_2c1f8">
#   <thead>
#     <tr>
#       <th id="T_2c1f8_level0_col0" class="col_heading level0 col0" >tokens</th>
#       <th id="T_2c1f8_level0_col1" class="col_heading level0 col1" >probabilities</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2c1f8_row0_col0" class="data row0 col0" > not</td>
#       <td id="T_2c1f8_row0_col1" class="data row0 col1" >0.749063</td>
#     </tr>
#     <tr>
#       <td id="T_2c1f8_row1_col0" class="data row1 col0" > to</td>
#       <td id="T_2c1f8_row1_col1" class="data row1 col1" >0.062379</td>
#     </tr>
#     <tr>
#       <td id="T_2c1f8_row2_col0" class="data row2 col0" > be</td>
#       <td id="T_2c1f8_row2_col1" class="data row2 col1" >0.030198</td>
#     </tr>
#     <tr>
#       <td id="T_2c1f8_row3_col0" class="data row3 col0" > have</td>
#       <td id="T_2c1f8_row3_col1" class="data row3 col1" >0.009973</td>
#     </tr>
#     <tr>
#       <td id="T_2c1f8_row4_col0" class="data row4 col0" > never</td>
#       <td id="T_2c1f8_row4_col1" class="data row4 col1" >0.007600</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_tokens_df(predict_next_tokens("For God so loved the", 5))
# Out:
# <style type="text/css">
# #T_553e6_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_553e6_row1_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_553e6_row2_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_553e6_row3_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_553e6_row4_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_553e6">
#   <thead>
#     <tr>
#       <th id="T_553e6_level0_col0" class="col_heading level0 col0" >tokens</th>
#       <th id="T_553e6_level0_col1" class="col_heading level0 col1" >probabilities</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_553e6_row0_col0" class="data row0 col0" > loved</td>
#       <td id="T_553e6_row0_col1" class="data row0 col1" >0.743032</td>
#     </tr>
#     <tr>
#       <td id="T_553e6_row1_col0" class="data row1 col0" > help</td>
#       <td id="T_553e6_row1_col1" class="data row1 col1" >0.091278</td>
#     </tr>
#     <tr>
#       <td id="T_553e6_row2_col0" class="data row2 col0" > love</td>
#       <td id="T_553e6_row2_col1" class="data row2 col1" >0.016821</td>
#     </tr>
#     <tr>
#       <td id="T_553e6_row3_col0" class="data row3 col0" > that</td>
#       <td id="T_553e6_row3_col1" class="data row3 col1" >0.016379</td>
#     </tr>
#     <tr>
#       <td id="T_553e6_row4_col0" class="data row4 col0" > pleased</td>
#       <td id="T_553e6_row4_col1" class="data row4 col1" >0.010759</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Analysis

# %% [markdown]
# **Q1: Explain the shape of `model_output.logits`.**
#
# The shape of `model_output.logits` contains three numbers. The first number is the batch size. The second number is the number of tokens in the phrase. The last number is the size of the vocabulary.

# %% [markdown]
# Q2: Change the -1 in the definition of `last_token_logits` to -3. What does the variable represent now? What does its argmax represent?
#
# Changing the -1 in the defintion of `last_token_logits` to -3 would now represent picking the third to last dimension of the logits tensor. This would start picking a subset of tokens from the sequence, rather than the last token. The argmax would then represent the most likely token chosen from that subset.

# %% [markdown]
# Q3: Let's think. The method in this notebook only get the scores for *one* next-token at a time. What if we wanted to do a whole sentence? We’d have to generate a token for each word in that sentence. What are a few different ways we could we adapt the approach used in this notebook to generate a complete sentence?
#
# To think about different ways to do this, think about what decision(s) you have to make when generating each token.
#
# Note: you don't have to write any code to answer this question.
#
# One way we could change our appraoch is by iterating through each word in the sentence and generate the next token sequentially. We could potentially use a loop to predict the new token based on the previous token. We could also modify the input phrase to include special toekns that indicate sentence boundaries, which would allow the model to generate multiple sentences in one sequence.
